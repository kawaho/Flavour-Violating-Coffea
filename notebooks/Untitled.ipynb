# %%
import pandas as pd
df = pd.read_csv("../results/VBF_VBFcat.csv")
print(df)
# Out:
#     quantiles  lowerMVA    weight  weight2016  weight2017  weight2018  \
# 0           1  0.017540  0.266015    0.266015         0.0         0.0
# 1           2  0.198018  0.712058    0.712058         0.0         0.0
# 2           3  0.372586  0.273618    0.273618         0.0         0.0
# 3           4  0.425344  0.224050    0.224050         0.0         0.0
# 4           5  0.454011  0.426254    0.426254         0.0         0.0
# ..        ...       ...       ...         ...         ...         ...
# 95         96  0.994814  0.686288    0.686288         0.0         0.0
# 96         97  0.995249  0.646069    0.646069         0.0         0.0
# 97         98  0.995745  0.856686    0.856686         0.0         0.0
# 98         99  0.996572  1.020461    1.020461         0.0         0.0
# 99        100  0.997605  1.008236    1.008236         0.0         0.0
#
#          acc  weight_lhe0  weight_lhe1  weight_lhe2  ...  \
# 0   0.000091     0.000091     0.000091     0.000091  ...
# ...

# %%
print(df[['weight', 'weight_jesBBEC1_Down']])
# Out:
#       weight  weight_jesBBEC1_Down
# 0   0.266015              0.266015
# 1   0.712058              0.712058
# 2   0.273618              0.268320
# 3   0.224050              0.212263
# 4   0.426254              0.389577
# ..       ...                   ...
# 95  0.686288              0.723715
# 96  0.646069              0.585845
# 97  0.856686              0.883161
# 98  1.020461              1.031980
# 99  1.008236              0.996381
#
# [100 rows x 2 columns]
