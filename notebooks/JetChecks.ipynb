# %%
from coffea.util import save, load
from coffea import hist
histo_dict = load("../results/2017/makeHist/output_jetcheck2.coffea")[0]

list_of_vars = ['MET', 'j1Pt', 'j2Pt', 'njets']
list_of_labels = [r"$Type\ 1\ PF\ E^{miss}_{T}$ [GeV]", r"$p^{j_{1}}_{T}$ [GeV]", r"$p^{j_{2}}_{T}$ [GeV]", "# of Jets"]
list_of_samples = ['data', r'$t\bar{t}$,t+Jets', 'GluGlu_LFV_HToEMu_M125', 'VBF_LFV_HToEMu_M125', 'Diboson']
list_of_sample_labels = ['data', 'TTTo2L2Nu', 'GluGlu_LFV_HToEMu_M125', 'VBF_LFV_HToEMu_M125', 'Diboson']

label_dict = {
    'data': 'data',
    r'$t\bar{t}$,t+Jets': 'TTTo2L2Nu',
    'GluGlu_LFV_HToEMu_M125': 'GluGlu_LFV_HToEMu_M125',
    '_LFV_HToEMu_M125': r'DY+Jets',
    "Stat. unc.": "Stat. unc."
}


# %matplotlib inline
ax_list = []
fig_list = []

from coffea import hist
for label_, var_ in zip(list_of_labels, list_of_vars):
    histo = histo_dict[var_]
    
    import matplotlib.pyplot as plt
    fig, ax = plt.subplots(figsize=(12,8), dpi=100)
    data = histo[list_of_samples, :]

    import matplotlib.pyplot as plt
    
    hist.plot1d(data, ax=ax, density=True)
    ax.set_xlabel(label_, fontsize='xx-large')
    ax.set_ylabel("AU", fontsize='xx-large')
    if var_ == 'j1Pt':
        ax.set_xlim(30,300)
    if var_ == 'j2Pt':
        ax.set_xlim(30,180)
    label_list = []
    for t in ax.get_legend_handles_labels():
        label_list.append(t)
        
    label_list[1] = ['TTTo2L2Nu', 'Diboson', 'GluGlu_LFV_HToEMu_M125', 'VBF_LFV_HToEMu_M125', 'data']

    ax.legend(handles=label_list[0], labels=label_list[1], fontsize='xx-large')
    #ax.set_title(sample_label, fontsize='xx-large')
    ax.minorticks_on()
    del fig
    del ax

# %%
from coffea.util import save, load
from coffea import hist
histo_dict = load("../results/2017/makeHist/output_jetcheck2.coffea")[0]

list_of_vars = ['MET', 'j1Pt', 'j2Pt', 'njets']
list_of_labels = [r"$Type\ 1\ PF\ E^{miss}_{T}$ [GeV]", r"$p^{j_{1}}_{T}$ [GeV]", r"$p^{j_{2}}_{T}$ [GeV]", "# of Jets"]
list_of_samples = ['data', r'$t\bar{t}$,t+Jets', 'GluGlu_LFV_HToEMu_M125', 'VBF_LFV_HToEMu_M125', 'Diboson']
list_of_sample_labels = ['data', 'TTTo2L2Nu', 'GluGlu_LFV_HToEMu_M125', 'VBF_LFV_HToEMu_M125', 'Diboson']

# %matplotlib inline
ax_list = []
fig_list = []

for sample_label, sample in zip(list_of_sample_labels, list_of_samples):
    for label_, var_ in zip(list_of_labels, list_of_vars):
        histo = histo_dict[var_]
        data = histo[[sample], :].to_hist()
#         ttbar = histo[[r'$t\bar{t}$,t+Jets'], :].to_hist()
#         diboson = histo[[r'$H\rightarrow e\mu$ (BR=1%)'], :].to_hist()
#         signal = histo[[r'$H\rightarrow e\mu$ (BR=1%)'], :].to_hist()

        import matplotlib.pyplot as plt
        fig, ax = plt.subplots(figsize=(12,8), dpi=100)
        data.plot1d(ax=ax)
        ax.set_xlabel(label_, fontsize='xx-large')
        ax.set_ylabel("Events", fontsize='xx-large')
        ax.set_title(sample_label, fontsize='xx-large')
        ax.minorticks_on()
        del fig
        del ax

# %%
from coffea.util import save, load
from coffea import hist
histo_dict = load("../results/2017/makeHist/output_jetcheck2.coffea")[0]

list_of_samples = ['data', r'$t\bar{t}$,t+Jets', 'GluGlu_LFV_HToEMu_M125', 'VBF_LFV_HToEMu_M125', 'Diboson']
list_of_sample_labels = ['data', 'TTTo2L2Nu', 'GluGlu_LFV_HToEMu_M125', 'VBF_LFV_HToEMu_M125', 'Diboson']

list_of_vars = ['j1Eta-Phi', 'j2Eta-Phi', 'jEta-Phi']

# %matplotlib inline
ax_list = []
fig_list = []

for sample_label, sample in zip(list_of_sample_labels, list_of_samples):
    for label_, var_ in zip(list_of_labels, list_of_vars):
        histo = histo_dict[var_]
        data = histo.integrate('dataset',sample).to_hist()

        import matplotlib.pyplot as plt
        fig, ax = plt.subplots(figsize=(12,8), dpi=100)
        data.plot2d(ax=ax, cmap='jet')
        ax.xaxis.get_label().set_fontsize('xx-large')
        ax.yaxis.get_label().set_fontsize('xx-large')
        ax.set_title(sample_label, fontsize='xx-large')
        #cbar = fig.colorbar(magplot,ticks=ticks,orientation='vertical')
        del fig
        del ax

# %%
from coffea.util import save, load
from coffea import hist
histo_dict = load("../results/2017/makeHist/output_jetcheck2.coffea")[0]

list_of_vars = ['jEta-Pt']#'j1Eta-Pt', 'j2Eta-Pt']
list_of_vars_label = ['$\eta^{j}$', '$\eta^{j_{1}}$', '$\eta^{j_{2}}$']

list_of_samples = ['data', r'$t\bar{t}$,t+Jets', 'GluGlu_LFV_HToEMu_M125', 'VBF_LFV_HToEMu_M125', 'Diboson']
list_of_sample_labels = ['data', 'TTTo2L2Nu', 'GluGlu_LFV_HToEMu_M125', 'VBF_LFV_HToEMu_M125', 'Diboson']

# %matplotlib inline
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,AutoMinorLocator)   
import numpy as np
import matplotlib.pyplot as plt

for var_, var_label_ in zip(list_of_vars, list_of_vars_label):
    histo = histo_dict[var_]
    for sample_label, sample in zip(list_of_sample_labels, list_of_samples):
        data = histo.integrate('dataset', sample).to_hist()
        pt_axis = data.axes[1]
        fig, axes = plt.subplots(ncols=len(pt_axis), figsize=(12, 3), sharey=True, dpi=100)
        for i, ax in enumerate(axes):
            data[:, i].plot1d(ax=ax)#, alpha=0.5, edgecolor=(0, 0, 0, 0.3))
            ax.legend(title=r"$p_{T} \in$"+f"({pt_axis[i][0]}, {pt_axis[i][1]}]  GeV", loc='upper right')
            ax.set_ylim(0, max(data[:, ::sum].to_numpy()[0])*0.8)
            ax.xaxis.set_minor_locator(AutoMinorLocator())
            ax.set_xticks(np.arange(-5, 6, 1))
            if i == 0:
                ax.set_ylabel("Events")
            if i == 1:
                ax.set_title(sample_label)
                ax.set_xlabel(var_label_)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
from coffea.util import save, load
from coffea import hist
histo_dict = load("../results/2017/makeHist/output_jetcheck2.coffea")[0]

list_of_vars = ['j1Eta-Pt', 'j2Eta-Pt']
list_of_vars_label = ['$\eta^{j_{1}}$', '$\eta^{j_{2}}$']

list_of_samples = ['data', r'$t\bar{t}$,t+Jets', 'GluGlu_LFV_HToEMu_M125', 'VBF_LFV_HToEMu_M125', 'Diboson']
list_of_sample_labels = ['data', 'TTTo2L2Nu', 'GluGlu_LFV_HToEMu_M125', 'VBF_LFV_HToEMu_M125', 'Diboson']

# %matplotlib inline
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,AutoMinorLocator)   
import numpy as np

for var_, var_label_ in zip(list_of_vars, list_of_vars_label):
    histo = histo_dict[var_]
    for sample_label, sample in zip(list_of_sample_labels, list_of_samples):
        data = histo.integrate('dataset', sample).to_hist()
        fig, ax = plt.subplots(figsize=(12,8), dpi=100)
        data[:, ::sum].plot1d(ax=ax)#, alpha=0.5, edgecolor=(0, 0, 0, 0.3))
        ax.set_ylim(0, max(data[:, ::sum].to_numpy()[0])*1.1)
        ax.xaxis.set_minor_locator(AutoMinorLocator())
        ax.set_xticks(np.arange(-5, 6, 1))
        ax.set_ylabel("Events", fontsize='xx-large')
        ax.set_title(sample_label, fontsize='xx-large')
        ax.set_xlabel(var_label_, fontsize='xx-large')

# %%
from coffea.util import save, load
from coffea import hist
histo_dict = load("../results/2017/makeHist/output_jetcheck2.coffea")[0]

list_of_vars = ['j1Eta-Pt', 'j2Eta-Pt']
list_of_vars2 = ['j1Pt', 'j2Pt']
list_of_vars_label = ['$\eta^{j_{1}}$', '$\eta^{j_{2}}$']

list_of_samples = ['data', r'$t\bar{t}$,t+Jets', 'GluGlu_LFV_HToEMu_M125', 'VBF_LFV_HToEMu_M125', 'Diboson']
list_of_sample_labels = ['data', 'TTTo2L2Nu', 'GluGlu_LFV_HToEMu_M125', 'VBF_LFV_HToEMu_M125', 'Diboson']

# %matplotlib inline
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,AutoMinorLocator)   
import numpy as np

for var_, var_2, var_label_ in zip(list_of_vars, list_of_vars2, list_of_vars_label):
    data = histo_dict[var_]
    fig, ax = plt.subplots(figsize=(12,8), dpi=100)
    data = data.integrate(var_2)

    hist.plot1d(data, ax=ax, density=True)

    label_list = []
    for t in ax.get_legend_handles_labels():
        label_list.append(t)

    label_list[1] = ['TTTo2L2Nu', 'Diboson', 'GluGlu_LFV_HToEMu_M125', 'VBF_LFV_HToEMu_M125', 'data']

    from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,AutoMinorLocator)
    import numpy as np
    ax.legend(handles=label_list[0], labels=label_list[1], fontsize='x-large')
    ax.set_ylabel("AU", fontsize='xx-large')
    ax.set_xlabel(var_label_, fontsize='xx-large')
    ax.xaxis.set_minor_locator(AutoMinorLocator())
    ax.set_xticks(np.arange(-5, 6, 1))
